# %% [markdown]
# # ETL Pipeline Preparation
# Follow the instructions below to help you create your ETL pipeline.
# ### 1. Import libraries and load datasets.
# - Import Python libraries
# - Load `messages.csv` into a dataframe and inspect the first few lines.
# - Load `categories.csv` into a dataframe and inspect the first few lines.

# %%
# import libraries
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
# load messages dataset
messages = pd.read_csv("messages.csv").set_index('id')
messages.head()
# Out:
#                                               message  \
# id
# 2   Weather update - a cold front from Cuba that c...
# 7             Is the Hurricane over or is it not over
# 8                     Looking for someone but no name
# 9   UN reports Leogane 80-90 destroyed. Only Hospi...
# 12  says: west side of Haiti, rest of the country ...
#
#                                              original   genre
# id
# 2   Un front froid se retrouve sur Cuba ce matin. ...  direct
# 7                  Cyclone nan fini osinon li pa fini  direct
# 8   Patnm, di Maryani relem pou li banm nouvel li ...  direct
# 9   UN reports Leogane 80-90 destroyed. Only Hospi...  direct
# 12  facade ouest d Haiti et le reste du pays aujou...  direct

# %%
# load categories dataset
categories = pd.read_csv("categories.csv").set_index('id')
categories.head()
# Out:
#                                            categories
# id
# 2   related-1;request-0;offer-0;aid_related-0;medi...
# 7   related-1;request-0;offer-0;aid_related-1;medi...
# 8   related-1;request-0;offer-0;aid_related-0;medi...
# 9   related-1;request-1;offer-0;aid_related-1;medi...
# 12  related-1;request-0;offer-0;aid_related-0;medi...

# %% [markdown]
# ### 2. Merge datasets.
# - Merge the messages and categories datasets using the common id
# - Assign this combined dataset to `df`, which will be cleaned in the following steps

# %%
# merge datasets
df = messages.join(categories,on='id')
df.head()
# Out:
#                                               message  \
# id
# 2   Weather update - a cold front from Cuba that c...
# 7             Is the Hurricane over or is it not over
# 8                     Looking for someone but no name
# 9   UN reports Leogane 80-90 destroyed. Only Hospi...
# 12  says: west side of Haiti, rest of the country ...
#
#                                              original   genre  \
# id
# 2   Un front froid se retrouve sur Cuba ce matin. ...  direct
# 7                  Cyclone nan fini osinon li pa fini  direct
# 8   Patnm, di Maryani relem pou li banm nouvel li ...  direct
# 9   UN reports Leogane 80-90 destroyed. Only Hospi...  direct
# 12  facade ouest d Haiti et le reste du pays aujou...  direct
#
#                                            categories
# id
# 2   related-1;request-0;offer-0;aid_related-0;medi...
# 7   related-1;request-0;offer-0;aid_related-1;medi...
# 8   related-1;request-0;offer-0;aid_related-0;medi...
# 9   related-1;request-1;offer-0;aid_related-1;medi...
# 12  related-1;request-0;offer-0;aid_related-0;medi...

# %% [markdown]
# ### 3. Split `categories` into separate category columns.
# - Split the values in the `categories` column on the `;` character so that each value becomes a separate column. You'll find [this method](https://pandas.pydata.org/pandas-docs/version/0.23/generated/pandas.Series.str.split.html) very helpful! Make sure to set `expand=True`.
# - Use the first row of categories dataframe to create column names for the categories data.
# - Rename columns of `categories` with new column names.

# %%
df
# Out:
#                                                  message  \
# id
# 2      Weather update - a cold front from Cuba that c...
# 7                Is the Hurricane over or is it not over
# 8                        Looking for someone but no name
# 9      UN reports Leogane 80-90 destroyed. Only Hospi...
# 12     says: west side of Haiti, rest of the country ...
# 14                Information about the National Palace-
# 15                        Storm at sacred heart of jesus
# 16     Please, we need tents and water. We are in Sil...
# 17       I would like to receive the messages, thank you
# 18     I am in Croix-des-Bouquets. We have health iss...
# 20     There's nothing to eat and water, we starving ...
# 21     I am in Petionville. I need more information r...
# 22     I am in Thomassin number 32, in the area named...
# 24     Let's do it together, need food in Delma 75, i...
# 25     More information on the 4636 number in order f...
# 26     A Comitee in Delmas 19, Rue ( street ) Janvier...
# 27     We need food and water in Klecin 12. We are dy...
# 28     are you going to call me or do you want me to ...
# 30        I don't understand how to use this thing 4636.
# 31     I would like to know if the earthquake is over...
# 32     I would like to know if one of the radio ginen...
# 33                        I'm in Laplaine, I am a victim
# 34     There's a lack of water in Moleya, please info...
# 35     Those people who live at Sibert need food they...
# 36     I want to say hello, my message is to let you ...
# 37                    Can you tell me about this service
# 38     People I'm at Delma 2, we don't anything what ...
# 39     We are at Gressier we needs assistance right a...
# 41     How can we get water and food in Fontamara 43 ...
# 42     We need help. Carrefour has been forgotten com...
# ...                                                  ...
# 30233  The ability to pick dengue from influenza is c...
# 30234  A Federation chartered ship arrived from Lae w...
# 30235  The result is that in Aceh province many prefa...
# 30236  Otherwise, the risk is families fleeing again ...
# 30237  A United Nations team from the Electoral Assis...
# 30238  Senegal and Guinea-Bissau have agreed to condu...
# 30239  The President said that her Government always ...
# 30240  It was decided that all vehicle movement from ...
# 30241  The tendency to link deforestation with large ...
# 30242  Polio is a viral disease that attacks the nerv...
# 30243  The new constitution declares that 'Somalia is...
# 30245  We're providing clean water to people who woul...
# 30246  Relief items include towels, sanitary napkins,...
# 30247  In Aceh's Meulaboh town the UN refugee agency ...
# 30248  WHO is recruiting a sanitary engineer / consul...
# 30249  Following the severe floods which occurred ove...
# 30250  The closure has stopped 169 inbound flights an...
# 30251  BANGKOK, 24 January 2012 (NNT) - Prime Ministe...
# 30253  Cadmium, a metallic element widely used in bat...
# 30254  Epidemic surveillance: National Institute of C...
# 30255  2.1 Due to sporadic skirmishes in eastern D.R....
# 30256  No other army had gone to greater lengths to a...
# 30257  The delivery was made in conjunction with the ...
# 30258  However while ECOWAS wanted him to lead a 12-m...
# 30259  Hpakant, an area rich with coveted jade stones...
# 30261  The training demonstrated how to enhance micro...
# 30262  A suitable candidate has been selected and OCH...
# 30263  Proshika, operating in Cox's Bazar municipalit...
# 30264  Some 2,000 women protesting against the conduc...
# 30265  A radical shift in thinking came about as a re...
#
#                                                 original   genre  \
# id
# 2      Un front froid se retrouve sur Cuba ce matin. ...  direct
# 7                     Cyclone nan fini osinon li pa fini  direct
# 8      Patnm, di Maryani relem pou li banm nouvel li ...  direct
# 9      UN reports Leogane 80-90 destroyed. Only Hospi...  direct
# 12     facade ouest d Haiti et le reste du pays aujou...  direct
# 14                   Informtion au nivaux palais nationl  direct
# 15                           Cyclone Coeur sacr de jesus  direct
# 16     Tanpri nou bezwen tant avek dlo nou zon silo m...  direct
# 17                 Mwen ta renmen jouin messag yo. Merci  direct
# 18     Nou kwadebouke, nou gen pwoblem sant m yo nan ...  direct
# 20               Bon repo pa gen anyen menm grangou swaf  direct
# 21                M nan pv mvle plis enfomasyon sou 4636  direct
# 22     Mwen thomassin 32 nan pyron mwen ta renmen jwe...  direct
# 24     Ann fel ansanm bezwen manje nan delma 75 nan r...  direct
# 25     gen plis enfomasyon sou 4636 la pom w sim ap k...  direct
# 26     Komite katye delma 19 rue janvier imp charite ...  direct
# 27     Nou bezwen mange avek dlo nan klcin 12 LA LAFI...  direct
# 28     Eske se rele nap relem oubyen se mwen kap rele...  direct
# 30     Mwen pa konprann koman pou m itilize bagay 463...  direct
# 31     Mwen ta remen connin si trenblem de terre afin...  direct
# 32     Mwen ta renmen konnen eske ge jounalis radyo g...  direct
# 33     Mwen laplan mwen viktim kot yap bay d pou latr...  direct
# 34       Nan moleya pa gen dlo svp f konnen sa pou mwen.  direct
# 35      nou menm nan sibert nou grangou nou bezwen mange  direct
# 36     Mwen salye nou dab mesaj mwen an se jis nou ge...  direct
# 37                    Can you tell me about this service  direct
# 38     MEZANMI MWEN MWEN NAN DELMA 2 NOU TR MAN MAL N...  direct
# 39       Se gressier nou an difikilte tanpri vin ede nou  direct
# 41     Comment nou ka jwen dlo ak manje nan font 43 c...  direct
# 42     Nap di secours yo bliye kafou net sant m ap to...  direct
# ...                                                  ...     ...
# 30233                                                NaN    news
# 30234                                                NaN    news
# 30235                                                NaN    news
# 30236                                                NaN    news
# 30237                                                NaN    news
# 30238                                                NaN    news
# 30239                                                NaN    news
# 30240                                                NaN    news
# 30241                                                NaN    news
# 30242                                                NaN    news
# 30243                                                NaN    news
# 30245                                                NaN    news
# 30246                                                NaN    news
# 30247                                                NaN    news
# 30248                                                NaN    news
# 30249                                                NaN    news
# 30250                                                NaN    news
# 30251                                                NaN    news
# 30253                                                NaN    news
# 30254                                                NaN    news
# 30255                                                NaN    news
# 30256                                                NaN    news
# 30257                                                NaN    news
# 30258                                                NaN    news
# 30259                                                NaN    news
# 30261                                                NaN    news
# 30262                                                NaN    news
# 30263                                                NaN    news
# 30264                                                NaN    news
# 30265                                                NaN    news
#
#                                               categories
# id
# 2      related-1;request-0;offer-0;aid_related-0;medi...
# 7      related-1;request-0;offer-0;aid_related-1;medi...
# 8      related-1;request-0;offer-0;aid_related-0;medi...
# 9      related-1;request-1;offer-0;aid_related-1;medi...
# 12     related-1;request-0;offer-0;aid_related-0;medi...
# 14     related-0;request-0;offer-0;aid_related-0;medi...
# 15     related-1;request-0;offer-0;aid_related-0;medi...
# 16     related-1;request-1;offer-0;aid_related-1;medi...
# 17     related-0;request-0;offer-0;aid_related-0;medi...
# 18     related-1;request-1;offer-0;aid_related-1;medi...
# 20     related-1;request-1;offer-0;aid_related-1;medi...
# 21     related-0;request-0;offer-0;aid_related-0;medi...
# 22     related-1;request-1;offer-0;aid_related-1;medi...
# 24     related-1;request-1;offer-0;aid_related-1;medi...
# 25     related-1;request-0;offer-0;aid_related-0;medi...
# 26     related-1;request-1;offer-0;aid_related-1;medi...
# 27     related-1;request-1;offer-0;aid_related-1;medi...
# 28     related-0;request-0;offer-0;aid_related-0;medi...
# 30     related-0;request-0;offer-0;aid_related-0;medi...
# 31     related-1;request-0;offer-0;aid_related-0;medi...
# 32     related-1;request-0;offer-0;aid_related-0;medi...
# 33     related-1;request-1;offer-0;aid_related-1;medi...
# 34     related-1;request-1;offer-0;aid_related-1;medi...
# 35     related-1;request-1;offer-0;aid_related-1;medi...
# 36     related-1;request-0;offer-0;aid_related-0;medi...
# 37     related-0;request-0;offer-0;aid_related-0;medi...
# 38     related-1;request-1;offer-0;aid_related-1;medi...
# 39     related-1;request-1;offer-0;aid_related-1;medi...
# 41     related-1;request-1;offer-0;aid_related-1;medi...
# 42     related-1;request-1;offer-0;aid_related-1;medi...
# ...                                                  ...
# 30233  related-1;request-0;offer-0;aid_related-1;medi...
# 30234  related-1;request-0;offer-0;aid_related-1;medi...
# 30235  related-1;request-0;offer-0;aid_related-1;medi...
# 30236  related-0;request-0;offer-0;aid_related-0;medi...
# 30237  related-0;request-0;offer-0;aid_related-0;medi...
# 30238  related-1;request-0;offer-0;aid_related-1;medi...
# 30239  related-1;request-0;offer-0;aid_related-0;medi...
# 30240  related-1;request-0;offer-0;aid_related-1;medi...
# 30241  related-1;request-0;offer-0;aid_related-0;medi...
# 30242  related-0;request-0;offer-0;aid_related-0;medi...
# 30243  related-1;request-0;offer-0;aid_related-0;medi...
# 30245  related-1;request-0;offer-0;aid_related-1;medi...
# 30246  related-1;request-0;offer-0;aid_related-1;medi...
# 30247  related-1;request-0;offer-0;aid_related-1;medi...
# 30248  related-0;request-0;offer-0;aid_related-0;medi...
# 30249  related-1;request-0;offer-0;aid_related-0;medi...
# 30250  related-1;request-0;offer-0;aid_related-0;medi...
# 30251  related-1;request-0;offer-0;aid_related-1;medi...
# 30253  related-0;request-0;offer-0;aid_related-0;medi...
# 30254  related-1;request-0;offer-0;aid_related-1;medi...
# 30255  related-1;request-0;offer-0;aid_related-1;medi...
# 30256  related-1;request-1;offer-0;aid_related-0;medi...
# 30257  related-1;request-0;offer-0;aid_related-0;medi...
# 30258  related-0;request-0;offer-0;aid_related-0;medi...
# 30259  related-1;request-0;offer-0;aid_related-0;medi...
# 30261  related-0;request-0;offer-0;aid_related-0;medi...
# 30262  related-0;request-0;offer-0;aid_related-0;medi...
# 30263  related-1;request-0;offer-0;aid_related-0;medi...
# 30264  related-1;request-0;offer-0;aid_related-1;medi...
# 30265  related-1;request-0;offer-0;aid_related-0;medi...
#
# [26386 rows x 4 columns]

# %%
# create a dataframe of the 36 individual category columns
categories = df["categories"].str.split(";", expand = True)
categories.head()
# Out:
#            0          1        2              3               4   \
# id
# 2   related-1  request-0  offer-0  aid_related-0  medical_help-0
# 7   related-1  request-0  offer-0  aid_related-1  medical_help-0
# 8   related-1  request-0  offer-0  aid_related-0  medical_help-0
# 9   related-1  request-1  offer-0  aid_related-1  medical_help-0
# 12  related-1  request-0  offer-0  aid_related-0  medical_help-0
#
#                     5                    6           7           8   \
# id
# 2   medical_products-0  search_and_rescue-0  security-0  military-0
# 7   medical_products-0  search_and_rescue-0  security-0  military-0
# 8   medical_products-0  search_and_rescue-0  security-0  military-0
# 9   medical_products-1  search_and_rescue-0  security-0  military-0
# 12  medical_products-0  search_and_rescue-0  security-0  military-0
#
#                9        ...                    26                      27  \
# id                      ...
# 2   child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 7   child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 8   child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 9   child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 12  child_alone-0       ...         aid_centers-0  other_infrastructure-0
#
#                    28        29       30      31            32      33  \
# id
# 2   weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 7   weather_related-1  floods-0  storm-1  fire-0  earthquake-0  cold-0
# 8   weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 9   weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 12  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
#
#                  34               35
# id
# 2   other_weather-0  direct_report-0
# 7   other_weather-0  direct_report-0
# 8   other_weather-0  direct_report-0
# 9   other_weather-0  direct_report-0
# 12  other_weather-0  direct_report-0
#
# [5 rows x 36 columns]

# %%
# select the first row of the categories dataframe
row = categories.iloc[0,:]

# use this row to extract a list of new column names for categories.
# one way is to apply a lambda function that takes everything 
# up to the second to last character of each string with slicing
category_colnames = [col for col,_ in row.str.split('-')]
print(category_colnames)
# Out:
# ['related', 'request', 'offer', 'aid_related', 'medical_help', 'medical_products', 'search_and_rescue', 'security', 'military', 'child_alone', 'water', 'food', 'shelter', 'clothing', 'money', 'missing_people', 'refugees', 'death', 'other_aid', 'infrastructure_related', 'transport', 'buildings', 'electricity', 'tools', 'hospitals', 'shops', 'aid_centers', 'other_infrastructure', 'weather_related', 'floods', 'storm', 'fire', 'earthquake', 'cold', 'other_weather', 'direct_report']

# %%
# rename the columns of `categories`
categories.columns = category_colnames
categories.head()
# Out:
#       related    request    offer    aid_related    medical_help  \
# id
# 2   related-1  request-0  offer-0  aid_related-0  medical_help-0
# 7   related-1  request-0  offer-0  aid_related-1  medical_help-0
# 8   related-1  request-0  offer-0  aid_related-0  medical_help-0
# 9   related-1  request-1  offer-0  aid_related-1  medical_help-0
# 12  related-1  request-0  offer-0  aid_related-0  medical_help-0
#
#       medical_products    search_and_rescue    security    military  \
# id
# 2   medical_products-0  search_and_rescue-0  security-0  military-0
# 7   medical_products-0  search_and_rescue-0  security-0  military-0
# 8   medical_products-0  search_and_rescue-0  security-0  military-0
# 9   medical_products-1  search_and_rescue-0  security-0  military-0
# 12  medical_products-0  search_and_rescue-0  security-0  military-0
#
#       child_alone       ...           aid_centers    other_infrastructure  \
# id                      ...
# 2   child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 7   child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 8   child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 9   child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 12  child_alone-0       ...         aid_centers-0  other_infrastructure-0
#
#       weather_related    floods    storm    fire    earthquake    cold  \
# id
# 2   weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 7   weather_related-1  floods-0  storm-1  fire-0  earthquake-0  cold-0
# 8   weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 9   weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 12  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
#
#       other_weather    direct_report
# id
# 2   other_weather-0  direct_report-0
# 7   other_weather-0  direct_report-0
# 8   other_weather-0  direct_report-0
# 9   other_weather-0  direct_report-0
# 12  other_weather-0  direct_report-0
#
# [5 rows x 36 columns]

# %% [markdown]
# ### 4. Convert category values to just numbers 0 or 1.
# - Iterate through the category columns in df to keep only the last character of each string (the 1 or 0). For example, `related-0` becomes `0`, `related-1` becomes `1`. Convert the string to a numeric value.
# - You can perform [normal string actions on Pandas Series](https://pandas.pydata.org/pandas-docs/stable/text.html#indexing-with-str), like indexing, by including `.str` after the Series. You may need to first convert the Series to be of type string, which you can do with `astype(str)`.

# %%
for column in categories:
    # set each value to be the last character of the string
    categories[column] = categories[column].str.split("-",expand=True).iloc[:,1]
    
    # convert column from string to numeric
    categories[column] = categories[column].astype(int)
    categories.loc[categories[column]>1,column]=1
categories.head()
# Out:
#     related  request  offer  aid_related  medical_help  medical_products  \
# id
# 2         1        0      0            0             0                 0
# 7         1        0      0            1             0                 0
# 8         1        0      0            0             0                 0
# 9         1        1      0            1             0                 1
# 12        1        0      0            0             0                 0
#
#     search_and_rescue  security  military  child_alone      ...        \
# id                                                          ...
# 2                   0         0         0            0      ...
# 7                   0         0         0            0      ...
# 8                   0         0         0            0      ...
# 9                   0         0         0            0      ...
# 12                  0         0         0            0      ...
#
#     aid_centers  other_infrastructure  weather_related  floods  storm  fire  \
# id
# 2             0                     0                0       0      0     0
# 7             0                     0                1       0      1     0
# 8             0                     0                0       0      0     0
# 9             0                     0                0       0      0     0
# 12            0                     0                0       0      0     0
#
#     earthquake  cold  other_weather  direct_report
# id
# 2            0     0              0              0
# 7            0     0              0              0
# 8            0     0              0              0
# 9            0     0              0              0
# 12           0     0              0              0
#
# [5 rows x 36 columns]

# %% [markdown]
# ### 5. Replace `categories` column in `df` with new category columns.
# - Drop the categories column from the df dataframe since it is no longer needed.
# - Concatenate df and categories data frames.

# %%
# drop the original categories column from `df`
df = df.drop(["categories"],axis=1)

df.head()
# Out:
#                                               message  \
# id
# 2   Weather update - a cold front from Cuba that c...
# 7             Is the Hurricane over or is it not over
# 8                     Looking for someone but no name
# 9   UN reports Leogane 80-90 destroyed. Only Hospi...
# 12  says: west side of Haiti, rest of the country ...
#
#                                              original   genre
# id
# 2   Un front froid se retrouve sur Cuba ce matin. ...  direct
# 7                  Cyclone nan fini osinon li pa fini  direct
# 8   Patnm, di Maryani relem pou li banm nouvel li ...  direct
# 9   UN reports Leogane 80-90 destroyed. Only Hospi...  direct
# 12  facade ouest d Haiti et le reste du pays aujou...  direct

# %%
# concatenate the original dataframe with the new `categories` dataframe
df = df.join(categories,on='id')
df.head()
# Out:
#                                               message  \
# id
# 2   Weather update - a cold front from Cuba that c...
# 7             Is the Hurricane over or is it not over
# 8                     Looking for someone but no name
# 9   UN reports Leogane 80-90 destroyed. Only Hospi...
# 12  says: west side of Haiti, rest of the country ...
#
#                                              original   genre  related  \
# id
# 2   Un front froid se retrouve sur Cuba ce matin. ...  direct        1
# 7                  Cyclone nan fini osinon li pa fini  direct        1
# 8   Patnm, di Maryani relem pou li banm nouvel li ...  direct        1
# 9   UN reports Leogane 80-90 destroyed. Only Hospi...  direct        1
# 12  facade ouest d Haiti et le reste du pays aujou...  direct        1
#
#     request  offer  aid_related  medical_help  medical_products  \
# id
# 2         0      0            0             0                 0
# 7         0      0            1             0                 0
# 8         0      0            0             0                 0
# 9         1      0            1             0                 1
# 12        0      0            0             0                 0
#
#     search_and_rescue      ...        aid_centers  other_infrastructure  \
# id                         ...
# 2                   0      ...                  0                     0
# 7                   0      ...                  0                     0
# 8                   0      ...                  0                     0
# 9                   0      ...                  0                     0
# 12                  0      ...                  0                     0
#
#     weather_related  floods  storm  fire  earthquake  cold  other_weather  \
# id
# 2                 0       0      0     0           0     0              0
# 7                 1       0      1     0           0     0              0
# 8                 0       0      0     0           0     0              0
# 9                 0       0      0     0           0     0              0
# 12                0       0      0     0           0     0              0
#
#     direct_report
# id
# 2               0
# 7               0
# 8               0
# 9               0
# 12              0
#
# [5 rows x 39 columns]

# %% [markdown]
# ### 6. Remove duplicates.
# - Check how many duplicates are in this dataset.
# - Drop the duplicates.
# - Confirm duplicates were removed.

# %%
# check number of duplicates
df.duplicated().value_counts()
# Out:
# False    26214
# True      1036
# dtype: int64

# %%
# drop duplicates
df = df.drop_duplicates()

# %%
# check number of duplicates
df.duplicated().value_counts()
# Out:
# False    26214
# dtype: int64

# %% [markdown]
# ### 7. Save the clean dataset into an sqlite database.
# You can do this with pandas [`to_sql` method](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_sql.html) combined with the SQLAlchemy library. Remember to import SQLAlchemy's `create_engine` in the first cell of this notebook to use it below.

# %%
engine = create_engine('sqlite:///disaster.db')
df.to_sql('disaster_tweet', engine, index=False,if_exists='replace')

# %% [markdown]
# ### 8. Use this notebook to complete `etl_pipeline.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database based on new datasets specified by the user. Alternatively, you can complete `etl_pipeline.py` in the classroom on the `Project Workspace IDE` coming later.
